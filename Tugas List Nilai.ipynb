# %% [markdown]
# # LATIHAN 2 - Tugas List Nilai
#
# Diberikan sekumpulan Nilai Random antara 0 sampai dengan 100 sebanyak 250 nilai. Buatlah program untuk melakukan hal berikut:
#
# 1. Tampilkan Angka Ganjil dari ke 250 nilai tersebut
# 2. Tampilkan berapa banyak yang mendapatkan nilai lebih dari 70
# 3. Tampilkan standar deviasi dari sekumpulan nilai tersebut
# 4. Tampilkan nilai maksimum dan minimum
# 5. Tampilkan modus dari sekumpulan nilai tersebut

# %%
#Tugas List Nilai
import random

nilaiTugas = []
for i in range(250):
    nilaiTugas.append(random.randrange(1,100,1))

print(nilaiTugas)
# Out:
# [79, 32, 13, 73, 33, 62, 98, 56, 40, 20, 78, 9, 7, 31, 57, 5, 10, 50, 88, 58, 74, 13, 15, 3, 48, 19, 35, 63, 69, 92, 88, 6, 6, 74, 59, 8, 91, 76, 82, 7, 5, 63, 49, 89, 27, 43, 3, 14, 2, 58, 53, 50, 58, 53, 6, 35, 23, 34, 41, 74, 43, 51, 32, 56, 72, 11, 88, 42, 52, 54, 2, 89, 24, 59, 53, 76, 76, 3, 25, 96, 20, 68, 97, 99, 80, 84, 38, 99, 43, 53, 58, 65, 29, 13, 65, 1, 40, 41, 41, 40, 92, 65, 32, 78, 94, 99, 95, 50, 46, 37, 89, 18, 67, 66, 99, 31, 6, 77, 84, 63, 40, 47, 1, 4, 15, 41, 84, 25, 11, 30, 71, 78, 79, 11, 51, 47, 38, 20, 13, 82, 14, 24, 4, 53, 51, 95, 45, 64, 18, 69, 35, 80, 49, 89, 22, 72, 85, 74, 24, 76, 64, 90, 86, 85, 45, 80, 84, 58, 84, 68, 78, 79, 71, 52, 65, 30, 56, 31, 92, 48, 71, 93, 67, 96, 52, 87, 32, 17, 39, 65, 34, 40, 19, 31, 54, 59, 26, 68, 26, 44, 91, 4, 26, 24, 34, 46, 57, 54, 65, 71, 71, 57, 49, 48, 47, 29, 29, 89, 26, 82, 41, 13, 45, 97, 16, 93, 44, 76, 17, 69, 13, 85, 60, 77, 39, 94, 86, 31, 57, 65, 51, 28, 69, 76, 71, 80, 69, 99, 92, 97]

# %%
# Nilai Ganjil
for n in nilaiTugas:
    if n%2==1:
        print("Nilai Ganjil=", n)
# Out:
# Nilai Ganjil= 79
# Nilai Ganjil= 13
# Nilai Ganjil= 73
# Nilai Ganjil= 33
# Nilai Ganjil= 9
# Nilai Ganjil= 7
# Nilai Ganjil= 31
# Nilai Ganjil= 57
# Nilai Ganjil= 5
# Nilai Ganjil= 13
# Nilai Ganjil= 15
# Nilai Ganjil= 3
# Nilai Ganjil= 19
# Nilai Ganjil= 35
# Nilai Ganjil= 63
# Nilai Ganjil= 69
# Nilai Ganjil= 59
# Nilai Ganjil= 91
# Nilai Ganjil= 7
# Nilai Ganjil= 5
# Nilai Ganjil= 63
# Nilai Ganjil= 49
# Nilai Ganjil= 89
# Nilai Ganjil= 27
# Nilai Ganjil= 43
# Nilai Ganjil= 3
# Nilai Ganjil= 53
# Nilai Ganjil= 53
# Nilai Ganjil= 35
# Nilai Ganjil= 23
# Nilai Ganjil= 41
# Nilai Ganjil= 43
# Nilai Ganjil= 51
# Nilai Ganjil= 11
# Nilai Ganjil= 89
# Nilai Ganjil= 59
# Nilai Ganjil= 53
# Nilai Ganjil= 3
# Nilai Ganjil= 25
# Nilai Ganjil= 97
# Nilai Ganjil= 99
# Nilai Ganjil= 99
# Nilai Ganjil= 43
# Nilai Ganjil= 53
# Nilai Ganjil= 65
# Nilai Ganjil= 29
# Nilai Ganjil= 13
# Nilai Ganjil= 65
# Nilai Ganjil= 1
# Nilai Ganjil= 41
# Nilai Ganjil= 41
# Nilai Ganjil= 65
# Nilai Ganjil= 99
# ...

# %%
#Nilai >70
for n in nilaiTugas:
    if n>70:
        print("Nilai>70 =", n)
# Out:
# Nilai>70 = 79
# Nilai>70 = 73
# Nilai>70 = 98
# Nilai>70 = 78
# Nilai>70 = 88
# Nilai>70 = 74
# Nilai>70 = 92
# Nilai>70 = 88
# Nilai>70 = 74
# Nilai>70 = 91
# Nilai>70 = 76
# Nilai>70 = 82
# Nilai>70 = 89
# Nilai>70 = 74
# Nilai>70 = 72
# Nilai>70 = 88
# Nilai>70 = 89
# Nilai>70 = 76
# Nilai>70 = 76
# Nilai>70 = 96
# Nilai>70 = 97
# Nilai>70 = 99
# Nilai>70 = 80
# Nilai>70 = 84
# Nilai>70 = 99
# Nilai>70 = 92
# Nilai>70 = 78
# Nilai>70 = 94
# Nilai>70 = 99
# Nilai>70 = 95
# Nilai>70 = 89
# Nilai>70 = 99
# Nilai>70 = 77
# Nilai>70 = 84
# Nilai>70 = 84
# Nilai>70 = 71
# Nilai>70 = 78
# Nilai>70 = 79
# Nilai>70 = 82
# Nilai>70 = 95
# Nilai>70 = 80
# Nilai>70 = 89
# Nilai>70 = 72
# Nilai>70 = 85
# Nilai>70 = 74
# Nilai>70 = 76
# Nilai>70 = 90
# Nilai>70 = 86
# Nilai>70 = 85
# Nilai>70 = 80
# Nilai>70 = 84
# Nilai>70 = 84
# Nilai>70 = 78
# Nilai>70 = 79
# Nilai>70 = 71
# Nilai>70 = 92
# Nilai>70 = 71
# Nilai>70 = 93
# Nilai>70 = 96
# Nilai>70 = 87
# Nilai>70 = 91
# Nilai>70 = 71
# ...

# %%
#Standar Deviasi

#rata-rata
total = 0
for n in nilaiTugas:
    total= total + n
rerata = total/len(nilaiTugas)

#standar deviasi
selisihtotal = 0
for n in nilaiTugas:
    x=n-rerata
    pangkat=x**2
    selisihtotal=selisihtotal+pangkat
std_deviasi=(selisihtotal/(len(nilaiTugas)-1))**(0.5)

print("Standard Deviasi=",std_deviasi)
# Out:
# Standard Deviasi= 27.855014473614993

# %%
#Nilai maksimum dan minimum
maksimum=0
for n in nilaiTugas:
    if n>maksimum:
        maksimum=n
print("Nilai Maksimum=",maksimum)

minimum=99
for n in nilaiTugas:
    if n<minimum:
        minimum=n
print("Nilai Minimum=", minimum)
# Out:
# Nilai Maksimum= 99
# Nilai Minimum= 1

# %%
#Nilai modus
modus=nilaiTugas[0]
jumlah=nilaiTugas.count(modus)
for b in nilaiTugas:
    jumlah_b=nilaiTugas.count(n)
    if jumlah_b>jumlah:
        modus=b
        jumlah=jumlah_b
print("Nilai Modus=", modus)
# Out:
# Nilai Modus= 79
