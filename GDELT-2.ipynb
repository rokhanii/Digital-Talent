# %%
import pandas as pd
import numpy as np
data = pd.read_csv('data kemiskinan.csv', delimiter = ',', encoding = "ISO-8859-1")
data.head()
# Out:
#   Provinsi Jumlah Penduduk Miskin Menurut Provinsi (Ribu Jiwa) Unnamed: 2  \
# 0      NaN                                          Perkotaan         NaN
# 1      NaN                                               2007        2008
# 2      NaN                                            Tahunan     Tahunan
# 3     ACEH                                              218.8       195.8
# 4    SUMUT                                              833.5       761.7
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5          Unnamed: 6  \
# 0        NaN        NaN        NaN                 NaN
# 1       2009       2010       2011                2012
# 2    Tahunan    Tahunan    Tahunan  Semester 1 (Maret)
# 3     182.19     173.37     176.02               171.8
# 4     688.04        689     691.13              669.25
#
#                Unnamed: 7          Unnamed: 8              Unnamed: 9  \
# 0                     NaN                 NaN                     NaN
# ...

# %%
# data.drop([0, 2])

# %%
# data.drop(data_kemiskinan.ix[:,'Jumlah Penduduk Miskin Menurut Provinsi (Ribu Jiwa)':'Unnamed: 49'].head(0).columns, axis=1)

# %%
data2 = data.drop(data.loc[:,'Jumlah Penduduk Miskin Menurut Provinsi (Ribu Jiwa)':'Unnamed: 43'].head(0).columns, axis=1)
data2.head()
# Out:
#   Provinsi         Unnamed: 44             Unnamed: 45         Unnamed: 46  \
# 0      NaN                 NaN                     NaN                 NaN
# 1      NaN                2013                     NaN                2014
# 2      NaN  Semester 1 (Maret)  Semester 2 (September)  Semester 1 (Maret)
# 3     ACEH              840.71                  855.71              881.26
# 4    SUMUT             1339.16                  1390.8             1286.67
#
#               Unnamed: 47         Unnamed: 48             Unnamed: 49  \
# 0                     NaN                 NaN                     NaN
# 1                     NaN                2015                     NaN
# 2  Semester 2 (September)  Semester 1 (Maret)  Semester 2 (September)
# 3                  837.42              851.59                  859.41
# 4                  1360.6             1463.67                 1508.14
#
#           Unnamed: 50             Unnamed: 51         Unnamed: 52  \
# ...

# %%
data3 = data2.drop(columns=['Unnamed: 54'])
data3
# Out:
#        Provinsi         Unnamed: 44             Unnamed: 45  \
# 0           NaN                 NaN                     NaN
# 1           NaN                2013                     NaN
# 2           NaN  Semester 1 (Maret)  Semester 2 (September)
# 3          ACEH              840.71                  855.71
# 4         SUMUT             1339.16                  1390.8
# 5        SUMBAR              407.47                  380.63
# 6          RIAU              469.28                  522.53
# 7         JAMBI              266.15                  281.57
# 8        SUMSEL             1110.37                 1108.21
# 9      BENGKULU              327.35                  320.41
# 10      LAMPUNG             1163.06                 1134.28
# 11   KEP. BABEL               69.22                    70.9
# 12    KEP. RIAU              126.66                  125.02
# 13  DKI JAKARTA              354.19                   375.7
# 14        JABAR             4297.04                 4382.65
# ...

# %%
data4 = data3.dropna()
data4.tail()
# Out:
#        Provinsi Unnamed: 44 Unnamed: 45 Unnamed: 46 Unnamed: 47 Unnamed: 48  \
# 33       MALUKU      321.84      322.51      316.11      307.02      328.41
# 34        MALUT       83.44       85.82       82.64       84.79        79.9
# 35  PAPUA BARAT      224.27      234.23      229.43      225.46      225.36
# 36        PAPUA     1017.36     1057.98       924.4      864.11      859.15
# 37    INDONESIA     28066.6    28553.93    28280.01    27727.78    28592.79
#
#    Unnamed: 49 Unnamed: 50 Unnamed: 51 Unnamed: 52 Unnamed: 53
# 33      327.78      327.72      331.79      320.51      320.42
# 34       72.65       74.68        76.4       76.47       78.28
# 35      225.54       225.8       223.6      228.38      212.86
# 36      898.21      911.33      914.87      897.69      910.42
# 37    28513.57    28005.39    27764.32    27771.22    26582.99

# %%
data5 = data4.iloc[:-1]
data5.tail()
# Out:
#        Provinsi Unnamed: 44 Unnamed: 45 Unnamed: 46 Unnamed: 47 Unnamed: 48  \
# 32       SULBAR         154       154.2      153.89      154.69      160.48
# 33       MALUKU      321.84      322.51      316.11      307.02      328.41
# 34        MALUT       83.44       85.82       82.64       84.79        79.9
# 35  PAPUA BARAT      224.27      234.23      229.43      225.46      225.36
# 36        PAPUA     1017.36     1057.98       924.4      864.11      859.15
#
#    Unnamed: 49 Unnamed: 50 Unnamed: 51 Unnamed: 52 Unnamed: 53
# 32      153.21      152.73       146.9      149.76      149.47
# 33      327.78      327.72      331.79      320.51      320.42
# 34       72.65       74.68        76.4       76.47       78.28
# 35      225.54       225.8       223.6      228.38      212.86
# 36      898.21      911.33      914.87      897.69      910.42

# %%
data5.columns = ['Provinsi','2013/1','2013/2','2014/1','2014/2', '2015/1','2015/2', '2016/1','2016/2','2017/1','2017/2']
data5.tail()
# Out:
#        Provinsi   2013/1   2013/2  2014/1  2014/2  2015/1  2015/2  2016/1  \
# 32       SULBAR      154    154.2  153.89  154.69  160.48  153.21  152.73
# 33       MALUKU   321.84   322.51  316.11  307.02  328.41  327.78  327.72
# 34        MALUT    83.44    85.82   82.64   84.79    79.9   72.65   74.68
# 35  PAPUA BARAT   224.27   234.23  229.43  225.46  225.36  225.54   225.8
# 36        PAPUA  1017.36  1057.98   924.4  864.11  859.15  898.21  911.33
#
#     2016/2  2017/1  2017/2
# 32   146.9  149.76  149.47
# 33  331.79  320.51  320.42
# 34    76.4   76.47   78.28
# 35   223.6  228.38  212.86
# 36  914.87  897.69  910.42

# %%
ave_data = data5.copy()
ave_data['2013/1'] = pd.to_numeric(ave_data['2013/1'])
ave_data['2013/2'] = pd.to_numeric(ave_data['2013/2'])
ave_data['2014/1'] = pd.to_numeric(ave_data['2014/1'])
ave_data['2014/2'] = pd.to_numeric(ave_data['2014/2'])
ave_data['2015/1'] = pd.to_numeric(ave_data['2015/1'])
ave_data['2015/2'] = pd.to_numeric(ave_data['2015/2'])
ave_data['2016/1'] = pd.to_numeric(ave_data['2016/1'])
ave_data['2016/2'] = pd.to_numeric(ave_data['2016/2'])
ave_data['2017/1'] = pd.to_numeric(ave_data['2017/1'])
ave_data['2017/2'] = pd.to_numeric(ave_data['2017/2'])
ave_data['ave2013'] = ave_data[['2013/1', '2013/2']].mean(numeric_only = True, axis = 1)
ave_data['ave2014'] = ave_data[['2014/1', '2014/2']].mean(numeric_only = True, axis = 1)
ave_data['ave2015'] = ave_data[['2015/1', '2015/2']].mean(numeric_only = True, axis = 1)
ave_data['ave2016'] = ave_data[['2016/1', '2016/2']].mean(numeric_only = True, axis = 1)
ave_data['ave2017'] = ave_data[['2017/1', '2017/2']].mean(numeric_only = True, axis = 1)
ave_data
# Out:
#        Provinsi   2013/1   2013/2   2014/1   2014/2   2015/1   2015/2  \
# 3          ACEH   840.71   855.71   881.26   837.42   851.59   859.41
# 4         SUMUT  1339.16  1390.80  1286.67  1360.60  1463.67  1508.14
# 5        SUMBAR   407.47   380.63   379.20   354.74   379.61   349.53
# 6          RIAU   469.28   522.53   499.88   498.28   531.39   562.92
# 7         JAMBI   266.15   281.57   263.80   281.75   300.71   311.56
# 8        SUMSEL  1110.37  1108.21  1100.83  1085.80  1145.63  1112.53
# 9      BENGKULU   327.35   320.41   320.95   316.50   334.07   322.83
# 10      LAMPUNG  1163.06  1134.28  1142.92  1143.93  1163.49  1100.68
# 11   KEP. BABEL    69.22    70.90    71.64    67.23    74.09    66.62
# 12    KEP. RIAU   126.66   125.02   127.80   124.17   122.40   114.83
# 13  DKI JAKARTA   354.19   375.70   393.98   412.79   398.92   368.67
# 14        JABAR  4297.04  4382.65  4327.07  4238.96  4435.70  4485.65
# ...

# %%
data6 = ave_data.drop(ave_data.loc[:,'2013/1':'2017/2'].head(0).columns, axis=1)
data6
# Out:
#        Provinsi   ave2013   ave2014   ave2015   ave2016   ave2017
# 3          ACEH   848.210   859.340   855.500   844.875   851.205
# 4         SUMUT  1364.980  1323.635  1485.905  1454.250  1390.220
# 5        SUMBAR   394.050   366.970   364.570   374.035   362.250
# 6          RIAU   495.905   499.080   547.155   508.495   505.505
# 7         JAMBI   273.860   272.775   306.135   290.305   282.580
# 8        SUMSEL  1109.290  1093.315  1129.080  1098.845  1086.840
# 9      BENGKULU   323.880   318.725   328.450   327.105   309.800
# 10      LAMPUNG  1148.670  1143.425  1132.085  1154.690  1107.735
# 11   KEP. BABEL    70.060    69.435    70.355    71.915    75.145
# 12    KEP. RIAU   125.840   125.985   118.615   119.775   126.900
# 13  DKI JAKARTA   364.945   403.385   383.795   385.070   391.410
# 14        JABAR  4339.845  4283.015  4460.675  4196.220  3971.425
# 15       JATENG  4718.910  4699.135  4541.410  4500.320  4324.105
# ...

# %%
data6.columns = ['Provinsi','2013','2014','2015','2016','2017']
data6.tail()
# Out:
#        Provinsi      2013     2014     2015     2016     2017
# 32       SULBAR   154.100  154.290  156.845  149.815  149.615
# 33       MALUKU   322.175  311.565  328.095  329.755  320.465
# 34        MALUT    84.630   83.715   76.275   75.540   77.375
# 35  PAPUA BARAT   229.250  227.445  225.450  224.700  220.620
# 36        PAPUA  1037.670  894.255  878.680  913.100  904.055

# %%
data_kemiskinan = data6.set_index('Provinsi')
data_kemiskinan
# Out:
#                  2013      2014      2015      2016      2017
# Provinsi
# ACEH          848.210   859.340   855.500   844.875   851.205
# SUMUT        1364.980  1323.635  1485.905  1454.250  1390.220
# SUMBAR        394.050   366.970   364.570   374.035   362.250
# RIAU          495.905   499.080   547.155   508.495   505.505
# JAMBI         273.860   272.775   306.135   290.305   282.580
# SUMSEL       1109.290  1093.315  1129.080  1098.845  1086.840
# BENGKULU      323.880   318.725   328.450   327.105   309.800
# LAMPUNG      1148.670  1143.425  1132.085  1154.690  1107.735
# KEP. BABEL     70.060    69.435    70.355    71.915    75.145
# KEP. RIAU     125.840   125.985   118.615   119.775   126.900
# DKI JAKARTA   364.945   403.385   383.795   385.070   391.410
# JABAR        4339.845  4283.015  4460.675  4196.220  3971.425
# JATENG       4718.910  4699.135  4541.410  4500.320  4324.105
# DI Y          542.690   538.730   517.895   491.885   477.430
# ...

# %%
data_kemiskinan.describe()
# Out:
#               2013         2014         2015         2016         2017
# count    34.000000    34.000000    34.000000    34.000000    34.000000
# mean    833.840735   824.829853   839.800294   820.142794   799.327059
# std    1249.605304  1236.321333  1240.719226  1204.484994  1152.341352
# min      40.310000    40.310000    40.310000    44.075000    49.015000
# 25%     193.405000   196.700000   208.672500   202.048750   198.433750
# 50%     373.267500   378.412500   374.182500   379.552500   375.185000
# 75%     841.796250   853.336250   849.403750   834.136250   843.283750
# max    4818.540000  4767.605000  4782.545000  4670.915000  4511.140000

# %%
# data6.columns

# %%
import matplotlib.pyplot as plt
# ax = ave_data.groupby('Provinsi')
# ax = ax.plot(kind='bar', title ="Rata-Rata Berdasarkan Tahun", legend=True, fontsize=12)
# # ax.set_xlabel("Provinsi", fontsize=12)
# ax.set_ylabel("ave2017", fontsize=12)

# %%
# data_kemiskinanfix = pd.DataFrame(data_kemiskinan,columns=['2013', '2014', '2015', '2016', '2017'])
# data_kemiskinanfix.plot.bar()
# apa = pd.DataFrame(ave_data,columns=['ave2016', 'ave2017'])
# apa = apa.plot(kind='bar',figsize=(10,8), title ="Kemiskinan 2016-2017", legend=True, fontsize=12)
# apa.set_xlabel("Provinsi", fontsize=8)
# apa.set_ylabel("Tahun", fontsize=8)

data_kemiskinanfix = pd.DataFrame(data_kemiskinan,columns=['2013', '2014', '2015', '2016', '2017'])
data_kemiskinanfix.plot(kind='bar',figsize=(10,10),title = "Kemiskinan 2013-2017", fontsize = 12)
# Out:
# <img src="data:image/png;base64,..." width="998.8889153504084">

# %%
ax = ave_data.groupby('Provinsi').mean()['ave2016']
ax = ax.plot(kind='bar', title ="Rata-Rata Berdasarkan Tahun", legend=True, fontsize=12)
ax.set_xlabel("Provinsi", fontsize=12)
ax.set_ylabel("Tahun", fontsize=12)
# Out:
# Text(0,0.5,'Tahun')

# %%
df = pd.DataFrame(data_kemiskinan)
# ax = df.plot.bar(stacked=True)
# data_kemiskinanfix.plot(kind='bar',figsize=(20,20),title = "Kemiskinan 2013-2017", fontsize = 12)
# df = pd.DataFrame({'a' : a,'b' : b, 'c' : c})
# ax = df.plot.barh(stacked=True);
# df = pd.DataFrame({'a' : a,'b' : b, 'c' : c})
# ax = df.plot.barh(stacked=True);
ax = df.plot(kind="bar",stacked=True, figsize=(10,10),title = "Kemiskinan 2013-2017", fontsize = 12)
# ax.figure.set_size_inches(10,5)

ax.set_title("Kemiskinan 2013-2017")
ax.legend(loc='upper left')

# ax.set_title("My ax title")
# ax.legend(loc='upper left')
# Out:
# <img src="data:image/png;base64,..." width="998.8889153504084">

# %%
# import packages
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

fig1 = plt.figure()

# %matplotlib notebook

# load data
# revels_data = pd.read_csv("directory.data.txt")
# rd = revels_data
data_kemiskinanfix = pd.DataFrame(data_kemiskinan,columns=['2013', '2014', '2015', '2016', '2017'])
ax = data_kemiskinanfix.plot(stacked=True)

# grouped bar plot
grouped = ax.groupby(['Provinsi', '2013', '2014', '2015', '2016', '2017'])["Contents"].sum().unstack().fillna(0)
grouped.plot(kind="bar", stacked=True, color=["#a2653e", "#a6814c", "#fd5956", "#fd8d49", "#9c6da5", "#c9ae74"])

# title and axis labels
plt.title("NUMBER OF REVELS PER PACKET", weight="bold")
plt.ylabel("Contents")
plt.xlabel("Packet")

# plot median line
median = 19
plt.axhline(median, color='grey', linestyle='dashed', linewidth=0.5)

# legend properties
plt.legend(loc=2, prop={"size":7})

# extend y axis to fit legend in
axes = plt.gca()
axes.set_ylim([0,30])

# show plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# <img src="data:image/png;base64,..." width="638.888905813665">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-5bae918d1fa6> in <module>()
#      15
#      16 # grouped bar plot
# ---> 17 grouped = ax.groupby(['Provinsi', '2013', '2014', '2015', '2016', '2017'])
#      18 grouped.plot(kind="bar", stacked=True, color=["#a2653e", "#a6814c", "#fd5956", "#fd8d49", "#9c6da5", "#c9ae74"])
#      19
#
# AttributeError: 'AxesSubplot' object has no attribute 'groupby'

# %%
data_kemiskinan = data5.set_index('Provinsi')
data_kemiskinan
# Out:
#                        2016/1   2016/2   2017/1   2017/2
# Provinsi
# ACEH                   848.44   841.31   872.61    829.8
# SUMATERA UTARA        1455.95  1452.55  1453.87  1326.57
# SUMATERA BARAT         371.56   376.51   364.51   359.99
# RIAU                    515.4   501.59   514.62   496.39
# JAMBI                   289.8   290.81   286.55   278.61
# SUMATERA SELATAN      1101.19   1096.5  1086.92  1086.76
# BENGKULU               328.61    325.6   316.98   302.62
# LAMPUNG                1169.6  1139.78  1131.73  1083.74
# KEP. BANGKA BELITUNG    72.76    71.07    74.09     76.2
# KEP. RIAU              120.41   119.14   125.37   128.43
# DKI JAKARTA             384.3   385.84   389.69   393.13
# JAWA BARAT            4224.33  4168.11  4168.44  3774.41
# JAWA TENGAH           4506.89  4493.75  4450.72  4197.49
# DI YOGYAKARTA          494.94   488.83   488.53   466.33
# JAWA TIMUR             4703.3  4638.53  4617.01  4405.27
# ...

# %%
# Ukuran Penyebaran Data
data_kemiskinan.count()
# Out:
# 2016/1    34
# 2016/2    34
# 2017/1    34
# 2017/2    34
# dtype: int64

# %%
#Ukuran Pemusatan Data
